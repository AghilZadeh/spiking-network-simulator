# %% [markdown]
# ## Inhibitory network simulation for paradoxical effect

# %%
import neurosimulator as ns
import numpy as np

# %%
from populations import OnePopulation
OnePopulation.MeanIx[0] = 30
OnePopulation.SigmaIx[0] = 2
OnePopulation.CP[0] = 1
OnePopulation.NN[0] = 1000
OnePopulation.CW[0] = -1
ns.initNetwork(OnePopulation)

# %% [markdown]
# ## Increasing Input

# %%
# %matplotlib notebook
ns.rundynamics(200, []);
ns.runplot(1000, 'all');
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
